# %% [markdown]
# # <center> 🐼 Pandas

# %% [markdown]
# ## Descargar dataset

# %%
# !wget -P ./../data/ https://raw.githubusercontent.com/pbonillor/DATA_SCIENCE_CON_PYTHON/main/MODULO_I/telecom_churn.csv
# Out:
# --2023-10-13 10:59:37--  https://raw.githubusercontent.com/pbonillor/DATA_SCIENCE_CON_PYTHON/main/MODULO_I/telecom_churn.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 310007 (303K) [text/plain]
# Saving to: ‘./../data/telecom_churn.csv’
#
# telecom_churn.csv   100%[===================>] 302.74K  --.-KB/s    in 0.04s
#
# 2023-10-13 10:59:37 (7.29 MB/s) - ‘./../data/telecom_churn.csv’ saved [310007/310007]

# %% [markdown]
# ## Importar Pandas

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %% [markdown]
# ## Cambiar ajustes (OPCIONAL)

# %%
pd.set_option("display.precision", 2)     # Mostrar solo 2 decimales (por defecto son 6)
pd.set_option('display.max_rows', 1000)   # Mostar como maximo 1000 filas (por defecto son 10)
pd.set_option('display.max_columns', 100) # Mostar como maximo 100 columnas (por defecto son 20)

# %% [markdown]
# ## Crear dataframe `df`

# %%
df = pd.read_csv('../data/telecom_churn.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %% [markdown]
# |  Variable  | Descripción | Tipo | Statistical Type |
# |---         |---       |---     |---
# | **State** | State abbreviation (like KS = Kansas) | String | Categorical |
# | **Account length** | How long the client has been with the company | Numerical | Quantitative |
# | **Area code** | Phone number prefix | Numerical | Categorical |
# | **International plan** | International plan (on/off) | String, "Yes"/"No" | Categorical/Binary |
# | **Voice mail plan** | Voicemail (on/off) | String, "Yes"/"No" | Categorical/Binary |
# | **Number vmail messages** | Number of voicemail messages | Numerical | Quantitative |
# | **Total day minutes** |  Total duration of daytime calls | Numerical | Quantitative |
# | **Total day calls** | Total number of daytime calls  | Numerical | Quantitative |
# | **Total day charge** | Total charge for daytime services | Numerical | Quantitative |
# | **Total eve minutes** | Total duration of evening calls | Numerical | Quantitative |
# | **Total eve calls** | Total number of evening calls | Numerical | Quantitative |
# | **Total eve charge** | Total charge for evening services | Numerical | Quantitative |
# | **Total night minutes** | Total duration of nighttime calls | Numerical | Quantitative |
# | **Total night calls** | Total number of nighttime calls | Numerical | Quantitative |
# | **Total night charge** | Total charge for nighttime services | Numerical | Quantitative |
# | **Total intl minutes** | Total duration of international calls  | Numerical | Quantitative |
# | **Total intl calls** | Total number of international calls | Numerical | Quantitative |
# | **Total intl charge** | Total charge for international calls | Numerical | Quantitative |
# | **Customer service calls** | Number of calls to customer service | Numerical | Categorical/Ordinal |

# %% [markdown]
# > # Recuerda
# > ### Columna = Variable = Feature = Dimension
# > ### Fila = Caso = Punto
#
# ## Ver ancho y alto de la tabla: `df.shape`

# %%
print("Shape:", df.shape)
print("Númber de filas:", df.shape[0])
print("Númber de columnas:", df.shape[1])
# Out:
# Shape: (3333, 21)
# Númber de filas: 3333
# Númber de columnas: 21

# %% [markdown]
# ## Ver los nombres de las variables: `df.columns`

# %%
print(df.columns)
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %% [markdown]
# ## Ver los typos de las variables: `df.info()`

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
#  14  total night calls       3333 non-null   int64
#  15  total night charge      3333 non-null   float64
#  16  total intl minutes      3333 non-null   float64
#  17  total intl calls        3333 non-null   int64
#  18  total intl charge       3333 non-null   float64
#  19  customer service calls  3333 non-null   int64
#  20  churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(4)
# memory usage: 524.2+ KB
# None

# %% [markdown]
# ## Mostrar datos estadísticos de las variables NUMÉRICAS

# %%
df.describe()
# Out:
#        account length  area code  number vmail messages  total day minutes  \
# count         3333.00    3333.00                3333.00            3333.00
# mean           101.06     437.18                   8.10             179.78
# std             39.82      42.37                  13.69              54.47
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# std              20.07              9.26              50.71            19.92
# min               0.00              0.00               0.00             0.00
# 25%              87.00             24.43             166.60            87.00
# 50%             101.00             30.50             201.40           100.00
# 75%             114.00             36.79             235.30           114.00
# max             165.00             59.64             363.70           170.00
#
#        total eve charge  total night minutes  total night calls  \
# count           3333.00              3333.00            3333.00
# mean              17.08               200.87             100.11
# std                4.31                50.57              19.57
# min                0.00                23.20              33.00
# 25%               14.16               167.00              87.00
# 50%               17.12               201.20             100.00
# 75%               20.00               235.30             113.00
# max               30.91               395.00             175.00
#
#        total night charge  total intl minutes  total intl calls  \
# count             3333.00             3333.00           3333.00
# mean                 9.04               10.24              4.48
# std                  2.28                2.79              2.46
# min                  1.04                0.00              0.00
# 25%                  7.52                8.50              3.00
# 50%                  9.05               10.30              4.00
# 75%                 10.59               12.10              6.00
# max                 17.77               20.00             20.00
#
#        total intl charge  customer service calls
# count            3333.00                 3333.00
# mean                2.76                    1.56
# std                 0.75                    1.32
# min                 0.00                    0.00
# 25%                 2.30                    1.00
# 50%                 2.78                    1.00
# 75%                 3.27                    2.00
# max                 5.40                    9.00

# %% [markdown]
# ## Mostrar datos estadísticos de las variables CATEGÓRICAS

# %%
df.describe(include=['object', 'bool'])
# Out:
#        state phone number international plan voice mail plan  churn
# count   3333         3333               3333            3333   3333
# unique    51         3333                  2               2      2
# top       WV     382-4657                 no              no  False
# freq     106            1               3010            2411   2850

# %% [markdown]
# ## Seleccionar 1 variable o columna (Pandas serie)

# %%
df.state
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: state, Length: 3333, dtype: object

# %%
df["state"]
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: state, Length: 3333, dtype: object

# %% [markdown]
# ## Seleccionar varias variables

# %%
df[["state", "account length", "area code"]]
# Out:
#      state  account length  area code
# 0       KS             128        415
# 1       OH             107        415
# 2       NJ             137        415
# 3       OH              84        408
# 4       OK              75        415
# ...    ...             ...        ...
# 3328    AZ             192        415
# 3329    WV              68        415
# 3330    RI              28        510
# 3331    CT             184        510
# 3332    TN              74        415
#
# [3333 rows x 3 columns]

# %% [markdown]
# ##  Variable numérica -> Min, max, mean, median, std, ...

# %%
print("Mínimo:  ", df['account length'].min())
print("Máximo:  ", df['account length'].max())
print("Media:   ", df['account length'].mean())
print("Mediana: ", df['account length'].median())
print("Desv est:", df['account length'].std())
# Out:
# Mínimo:   1
# Máximo:   243
# Media:    101.06480648064806
# Mediana:  101.0
# Desv est: 39.822105928595604

# %% [markdown]
# ## Variable categórica -> Recuentos por categoría

# %%
df['churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: churn, dtype: int64

# %%
df['churn'].value_counts(normalize=True)
# Out:
# False    0.86
# True     0.14
# Name: churn, dtype: float64

# %%
# Show top 10 in a dataframe
pd.DataFrame({  'Recuento':   df['state'].value_counts(),
                'Porcentaje': df['state'].value_counts(normalize=True) * 100
             }).head(10)
# Out:
#     Recuento  Porcentaje
# WV       106        3.18
# MN        84        2.52
# NY        83        2.49
# AL        80        2.40
# WI        78        2.34
# OH        78        2.34
# OR        78        2.34
# WY        77        2.31
# VA        77        2.31
# CT        74        2.22

# %% [markdown]
# ## Variables categóricas -> Recuentos en tabla cruzada
#
# #### También llamadas tablas de contingencia

# %%
pd.crosstab(df['churn'], df['international plan'])
# Out:
# international plan    no  yes
# churn
# False               2664  186
# True                 346  137

# %%
pd.crosstab(df['churn'], df['international plan'], margins=True)
# Out:
# international plan    no  yes   All
# churn
# False               2664  186  2850
# True                 346  137   483
# All                 3010  323  3333

# %%
pd.crosstab(df['churn'], df['voice mail plan'], normalize=True)
# Out:
# voice mail plan    no   yes
# churn
# False            0.60  0.25
# True             0.12  0.02

# %% [markdown]
# ## Varaibles numéricas y categóricas -> Agragaciones

# %%
df.pivot_table(['total day calls', 'total eve calls', 'total night calls'],
               ['state'], aggfunc='mean').head()
# Out:
#        total day calls  total eve calls  total night calls
# state
# AK               95.27            96.58              97.35
# AL               99.10            98.46              98.61
# AR              102.15            97.84              99.05
# AZ              100.11           102.41              99.98
# CA              104.50           103.09              99.21

# %%
df.pivot_table(['total day calls', 'total eve calls', 'total night calls'],
               ['state'], aggfunc='max').head()
# Out:
#        total day calls  total eve calls  total night calls
# state
# AK                 129              147                137
# AL                 139              144                152
# AR                 145              159                144
# AZ                 163              146                138
# CA                 150              143                126

# %%
df.pivot_table(['total day calls', 'total eve calls', 'total night calls'],
               ['state', "churn"], aggfunc='mean').head()
# Out:
#              total day calls  total eve calls  total night calls
# state churn
# AK    False            95.59            96.39              97.55
#       True             90.00            99.67              94.00
# AL    False            99.39            99.25              98.40
#       True             96.50            91.38             100.50
# AR    False           101.91            94.84              96.34

# %% [markdown]
# ## Filtros

# %% [markdown]
# ### Filtrar por una condición

# %%
df['churn']==True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: churn, Length: 3333, dtype: bool

# %%
df[ df['churn']==True ]
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 21      CO              77        408     393-7984                 no
# 33      AZ              12        408     360-1596                 no
# 41      MD             135        408     383-6029                yes
# 48      ID             119        415     398-1294                 no
# 54      WY              87        415     353-3759                 no
# 57      CO             121        408     370-7574                 no
# 69      TX             150        510     374-8042                 no
# 76      DC              82        415     374-5353                 no
# 77      NY             144        408     360-1171                 no
# 84      TX             106        510     395-3026                 no
# 86      IN              94        408     402-1251                 no
# 89      NJ             128        415     358-9095                 no
# 91      LA             155        415     334-1275                 no
# 98      MS             120        408     355-6291                 no
# 99      ID              77        415     362-9748                 no
# 115     ME              36        510     363-1069                yes
# 117     NV              74        415     355-6837                 no
# 126     MS             162        415     335-4858                 no
# 127     MS              61        510     414-8718                 no
# 144     VT             117        408     390-2390                yes
# 156     OH              83        415     370-9116                 no
# 181     AK             126        415     372-3750                 no
# 197     TX             208        510     378-3625                 no
# 198     ME             131        510     353-7292                yes
# 214     FL              70        510     366-6345                yes
# 218     MD             136        415     375-1476                 no
# 230     MD              93        408     360-3324                yes
# 235     MN             139        510     374-9107                 no
# 241     NV             137        415     338-1027                yes
# 244     VA             108        408     335-1697                 no
# 250     OR              33        415     380-2558                 no
# 258     KS              92        408     386-4170                yes
# 277     SD             144        408     339-3049                 no
# 289     OK              89        510     352-6976                 no
# 293     CT              96        415     387-5860                 no
# 301     FL             127        415     416-1676                 no
# 302     RI             121        408     329-7347                 no
# 306     VT             113        415     419-1714                 no
# 307     IN             122        408     336-3819                 no
# 310     MN              62        415     366-7912                 no
# 319     SD             128        510     413-9269                yes
# 331     MT              54        415     387-5453                 no
# 332     AL              86        415     380-3437                 no
# 340     GA              89        415     343-6940                 no
# 349     FL             100        510     420-7823                 no
# 354     MS              64        408     402-1942                yes
# 360     CO             159        408     341-4463                yes
# 365     CO             154        415     343-5709                 no
# 372     CA             151        415     357-1909                yes
# 378     MO              95        415     374-7787                yes
# 394     WI              16        510     405-5305                 no
# 397     OR              94        415     328-6011                 no
# 399     DC              66        415     402-5155                 no
# 407     DE             122        510     332-5521                 no
# 415     DE             113        415     352-4418                 no
# 416     DE             224        510     361-6563                yes
# 430     KS              46        510     365-5979                 no
# 437     OH             100        510     385-8997                 no
# 454     OH              97        408     405-6189                 no
# 455     MA              88        415     418-6737                 no
# 465     NV              71        415     352-8327                yes
# 466     FL             132        510     334-9505                 no
# 473     WV              72        510     418-6651                 no
# 491     AL              55        415     375-2975                yes
# 492     ME              92        415     376-8573                yes
# 498     ME              75        408     343-1965                yes
# 502     MI              93        415     366-7247                yes
# 507     MO              92        415     405-3916                 no
# 509     MS             118        415     397-9148                 no
# 514     AL              60        408     411-7778                yes
# 521     SC              88        510     394-8402                 no
# 542     MN             152        415     416-2778                yes
# 546     WI              69        510     418-6455                yes
# 547     VT              95        510     378-3508                yes
# 550     AK             111        415     364-7719                 no
# 552     GA              44        510     419-8987                 no
# 558     MT              74        408     339-7541                 no
# 569     NC             133        408     344-3160                yes
# 574     WV              44        510     419-1674                 no
# 580     IN             113        415     353-6007                 no
# 584     SD             104        510     420-9838                 no
# 588     OK             101        408     345-1524                 no
# 601     MA              62        415     386-2810                yes
# 605     MO             112        415     373-2053                 no
# 613     NV             105        415     380-7742                yes
# 619     KS             110        415     383-1657                yes
# 626     NJ              95        408     348-8015                yes
# 629     GA              76        415     372-6497                 no
# 649     MO              79        408     411-5958                 no
# 655     CA              79        510     416-8701                 no
# 660     MT             109        408     405-4920                 no
# 679     TX              75        415     384-2372                yes
# 715     WV             115        510     420-9971                yes
# 721     UT             103        510     327-3587                 no
# 730     WY              94        510     353-8363                 no
# 736     UT              68        415     398-3834                 no
# 737     KY              91        415     330-7754                yes
# 766     PA             122        415     383-4061                yes
# 771     WI             149        415     339-6637                yes
# 773     MA             127        408     371-9457                yes
# 787     NJ              24        408     393-7826                 no
# 792     NV              69        510     397-6789                yes
# 797     VA              68        408     364-9040                yes
# 815     KY              75        415     341-1191                 no
# 830     CO             121        408     409-4447                yes
# 832     SC              87        408     335-1874                 no
# 846     NE              96        415     410-6791                 no
# 851     MA             136        408     367-8168                yes
# 859     AL              93        408     374-9203                 no
# 871     MA              98        510     366-3358                 no
# 892     LA             109        415     395-6195                 no
# 894     ME              97        510     346-7656                 no
# 901     CT              23        510     370-5527                 no
# 904     MD              61        415     370-2688                 no
# 905     WV             161        415     418-9036                 no
# 911     AR             118        415     402-3892                 no
# 914     MO             179        510     355-2464                 no
# 933     KY              74        510     368-7555                yes
# 944     NV              81        415     399-9802                 no
# 946     NJ              46        408     332-5949                 no
# 966     NJ              48        510     408-4529                 no
# 968     NM             122        408     370-9755                 no
# 975     DE             129        510     332-6181                 no
# 977     GA              93        408     413-5190                 no
# 978     VT              63        415     394-7447                 no
# 985     NY              64        415     345-9140                yes
# 987     KS             110        415     369-8024                yes
# 1000    MI             133        408     387-9137                 no
# 1018    WY              76        415     408-6326                 no
# 1027    UT             161        510     329-2786                yes
# 1030    VA              99        415     400-6257                 no
# 1038    CA             112        415     338-6962                 no
# 1077    NY             108        415     344-7197                 no
# 1078    ME              80        408     333-7631                 no
# 1102    NJ             111        510     332-5084                 no
# 1105    NJ             135        510     401-8735                 no
# 1115    OH              98        408     368-1288                 no
# 1121    MI              91        415     390-7930                 no
# 1122    NE             159        415     362-5111                 no
# 1133    NV              64        408     350-7306                 no
# 1136    WY             106        415     338-6018                yes
# 1142    UT             105        415     385-8184                 no
# 1150    GA             132        415     368-5437                 no
# 1155    KS             167        415     409-4734                 no
# 1182    MD             172        408     346-5068                 no
# 1192    MD              88        415     358-4576                yes
# 1193    NM             119        415     352-5118                yes
# 1204    IL              78        415     343-7019                yes
# 1231    CO             105        408     334-8694                 no
# 1232    KS              24        510     369-5449                 no
# 1240    TN             108        510     356-8449                 no
# 1254    MN              62        510     390-9811                 no
# 1263    MA              40        408     351-7005                 no
# 1269    FL              55        510     364-7644                 no
# 1273    MT              28        415     357-9136                 no
# 1276    MI              51        415     373-1448                 no
# 1278    NY             163        408     413-2241                 no
# 1280    NC              58        510     375-4107                 no
# 1284    OR             135        415     377-1293                 no
# 1299    UT              49        415     394-4520                 no
# 1302    WA             171        408     419-1863                 no
# 1306    TX              82        415     395-9215                 no
# 1310    WA              45        510     399-3083                 no
# 1322    DE               2        415     415-8448                yes
# 1325    TN              17        510     382-5401                 no
# 1327    ID             193        415     411-4714                 no
# 1334    KS             126        408     379-8681                 no
# 1337    WY              97        510     346-1629                yes
# 1339    WA              90        415     374-9576                yes
# 1344    MA             111        415     387-7371                 no
# 1345    SD              98        415     392-2555                 no
# 1346    PA             106        408     403-9167                yes
# 1350    WA              55        408     357-6039                 no
# 1359    VT              73        415     414-1496                 no
# 1364    CT             115        415     339-1330                 no
# 1373    SC             108        415     399-6233                 no
# 1376    OH              65        415     405-3097                 no
# 1392    OK             101        415     413-4040                 no
# 1405    MT             125        510     366-5829                 no
# 1407    MS              73        415     412-2520                 no
# 1420    MI              81        415     393-6840                yes
# 1435    IL              89        415     380-4080                yes
# 1442    ME             102        510     390-9627                 no
# 1454    UT             133        408     398-8745                 no
# 1467    DE              67        415     413-7743                yes
# 1472    MD              76        415     400-7002                yes
# 1484    AR             107        415     343-5219                yes
# 1493    MT             126        415     344-3466                 no
# 1516    UT              68        415     403-8916                 no
# 1528    OH             143        415     337-7167                 no
# 1530    IA              81        510     377-1273                 no
# 1531    DE             138        510     380-7816                yes
# 1532    CA             103        415     402-6744                 no
# 1533    WY             127        510     400-2181                yes
# 1534    OR             136        510     366-1613                 no
# 1537    ME             118        408     384-8723                yes
# 1538    WV             113        415     341-7686                 no
# 1551    MI             225        415     371-2500                 no
# 1585    NJ              85        415     366-2273                 no
# 1593    KS             105        415     405-1108                yes
# 1601    AR              99        510     387-2604                yes
# 1614    MT             184        415     417-4810                 no
# 1619    NH             149        415     368-7706                 no
# 1635    AZ              66        510     337-8618                 no
# 1638    MD             116        408     405-2276                 no
# 1646    MN             173        510     372-7990                 no
# 1651    CT              64        415     406-9926                yes
# 1653    MD              93        510     384-3299                yes
# 1662    AL             197        415     395-7923                yes
# 1674    NV              76        510     377-4169                yes
# 1679    OK              82        510     393-4823                 no
# 1691    OR              95        415     348-5725                 no
# 1692    PA              79        415     365-2008                 no
# 1694    VT              99        415     380-8727                 no
# 1701    MA              34        415     374-1981                 no
# 1702    OR             140        415     333-5101                 no
# 1704    FL             144        510     384-5004                 no
# 1707    WV              50        408     348-7193                 no
# 1713    MO              76        510     418-7055                 no
# 1718    AZ             109        415     404-3106                yes
# 1731    TX              70        415     341-8719                 no
# 1736    NV             115        415     334-5029                 no
# 1739    NJ              80        415     330-4978                 no
# 1746    DC              60        408     355-3801                 no
# 1750    ME              23        510     376-9607                 no
# 1752    NY             181        415     421-8537                yes
# 1754    NC              54        415     407-7258                yes
# 1764    CT              77        415     335-6508                 no
# 1765    NM             111        415     348-6720                 no
# 1768    MN             115        510     390-5055                yes
# 1777    OR             149        415     331-1391                 no
# 1784    DE              51        415     420-6465                yes
# 1794    NY              54        415     348-6853                 no
# 1804    CT             125        415     409-7523                yes
# 1837    NH             117        510     397-1766                yes
# 1842    WA              97        408     373-8908                 no
# 1844    SC              77        510     369-7017                 no
# 1845    NC              80        415     420-8435                yes
# 1849    PA             119        408     342-4122                 no
# 1850    NC             162        408     340-1876                 no
# 1851    MO              85        510     383-6095                 no
# 1857    NM             107        415     407-2259                 no
# 1861    MA             119        408     417-3999                yes
# 1862    OH             133        408     379-1720                yes
# 1865    MI             146        408     405-7676                 no
# 1866    TX             119        510     361-2349                 no
# 1869    MS             101        408     387-5533                 no
# 1878    KY              39        415     359-4336                 no
# 1880    CT              56        415     406-3069                 no
# 1881    NE              76        415     334-6519                 no
# 1887    OK             105        510     405-4109                yes
# 1889    SD              91        415     357-5696                 no
# 1892    WI             147        415     405-5403                yes
# 1893    IN              68        510     330-9354                 no
# 1898    VT             159        415     335-2019                 no
# 1903    NJ              93        510     384-5632                yes
# 1904    WA             174        408     352-6068                 no
# 1912    NH             103        408     371-1727                 no
# 1919    WA             100        408     382-4932                 no
# 1933    PA             119        408     377-5043                 no
# 1934    HI             105        415     401-7359                 no
# 1935    MD             108        415     375-2184                yes
# 1939    AZ             113        510     403-9719                 no
# 1950    TX              52        415     364-9904                 no
# 1954    ND              71        510     373-8483                 no
# 1965    NY             139        510     399-7268                 no
# 1974    KY             113        408     403-2673                 no
# 1977    SC              49        415     340-4972                yes
# 1978    RI             106        510     417-4826                yes
# 1984    TN             112        415     339-6477                 no
# 2001    TX              73        408     340-8323                 no
# 2028    SD              93        510     408-4836                 no
# 2029    OK             154        415     374-8329                yes
# 2033    NJ             162        408     367-8692                 no
# 2038    TX             136        408     335-4888                 no
# 2059    KS              94        408     379-7215                 no
# 2069    OR              53        408     400-8375                 no
# 2076    NH              95        408     400-8538                yes
# 2099    MA              71        510     419-5171                 no
# 2103    NH              74        408     413-2194                 no
# 2106    GA             128        408     355-2634                yes
# 2107    MN             123        408     422-5350                 no
# 2112    LA             150        415     381-4029                 no
# 2113    NJ              60        408     335-2967                 no
# 2115    CA             138        510     388-6026                yes
# 2118    TX              37        510     346-2020                yes
# 2119    CA             111        408     329-9067                 no
# 2139    VA              92        510     411-2958                yes
# 2142    MT             100        415     385-7148                 no
# 2147    NE             126        415     387-1535                 no
# 2150    SC             212        415     336-8343                 no
# 2155    AL             172        408     359-5731                 no
# 2158    FL             166        510     367-1681                yes
# 2160    NV              94        408     351-4025                yes
# 2164    NC             115        510     329-9667                yes
# 2173    KS              47        510     418-5300                yes
# 2186    NM              41        415     327-8495                 no
# 2187    WA             167        415     416-5660                 no
# 2203    PA              97        510     365-7774                yes
# 2210    UT              71        415     367-3220                 no
# 2213    TX              98        415     406-2242                 no
# 2215    MS              13        415     413-7468                 no
# 2218    MI             116        408     379-2503                 no
# 2237    NV              88        415     364-3286                 no
# 2238    NE              61        408     420-8897                 no
# 2258    TN              80        415     351-7309                yes
# 2267    MS              29        510     401-6982                 no
# 2283    AR              98        415     328-7833                 no
# 2290    NV             113        510     342-8167                 no
# 2324    LA             124        510     348-4316                 no
# 2325    UT             110        415     375-3826                 no
# 2327    NY              82        415     356-5475                 no
# 2335    MN             124        510     371-6284                yes
# 2343    TN             120        408     410-7611                yes
# 2347    IL              68        415     340-6908                yes
# 2354    MT             102        408     399-2457                 no
# 2356    FL             105        415     358-2490                 no
# 2357    WI             153        510     349-3112                 no
# 2369    NY             112        415     391-1737                 no
# 2376    NV              42        415     352-5466                 no
# 2377    ND             101        415     364-5510                 no
# 2380    NJ              53        408     416-6886                 no
# 2386    CT             120        408     344-1136                yes
# 2387    MI             108        408     378-6276                 no
# 2388    SC             161        510     343-2592                 no
# 2389    SC             130        415     396-4410                 no
# 2397    MD             107        415     347-3406                 no
# 2401    NY             126        415     352-7752                yes
# 2402    NY              77        415     388-9285                 no
# 2405    ID              92        415     333-4594                 no
# 2407    TX             139        510     388-2240                yes
# 2412    WI              89        415     373-4264                 no
# 2415    DC             114        415     354-5689                 no
# 2419    CA              37        510     328-8980                 no
# 2420    MN             100        415     399-2151                yes
# 2421    CO             132        415     379-9524                 no
# 2428    MN              40        510     350-7114                 no
# 2432    PA              75        510     353-9998                 no
# 2437    CA             105        415     409-9911                 no
# 2451    NC             182        415     379-6970                 no
# 2468    WV             152        510     332-6139                yes
# 2472    IN             129        415     415-4564                 no
# 2479    ID             116        510     414-7090                yes
# 2489    RI             143        408     332-2889                 no
# 2493    KY              21        415     412-1991                 no
# 2515    MD             111        510     372-8883                 no
# 2526    NJ              57        510     330-2635                yes
# 2533    CO              92        415     408-3262                 no
# 2535    RI             125        408     410-3159                 no
# 2536    CT             119        408     344-5181                 no
# 2539    OR             138        415     384-7236                yes
# 2542    SC              19        510     408-5322                 no
# 2567    KY              58        415     409-2983                 no
# 2572    MN             152        415     378-9542                 no
# 2573    WV             124        415     344-1970                 no
# 2575    MS             131        415     333-9002                 no
# 2581    NY             123        415     329-6731                 no
# 2591    ND             122        408     395-1901                 no
# 2594    OH             115        510     348-1163                yes
# 2595    AL              25        408     337-4600                 no
# 2599    DE              97        510     354-7397                 no
# 2602    OK              86        510     397-3746                yes
# 2606    AR             145        415     332-5820                 no
# 2614    NH             125        415     357-1938                yes
# 2619    ND             147        408     409-4671                yes
# 2624    MI             105        415     376-5213                 no
# 2629    NH             141        415     402-3370                 no
# 2645    KS              91        408     382-8079                yes
# 2647    SC             116        408     373-6922                 no
# 2660    NJ              88        415     347-8659                 no
# 2662    VA              50        415     382-2182                yes
# 2664    NM             188        415     369-6890                yes
# 2666    RI             103        510     420-6324                yes
# 2672    MS              65        415     383-9306                yes
# 2673    ND             180        415     369-1929                 no
# 2677    IA              44        415     359-7426                 no
# 2681    SC             121        415     415-6347                 no
# 2687    MN             125        415     390-9735                yes
# 2694    MN             125        415     343-2689                 no
# 2696    MI              74        415     359-6232                 no
# 2700    SC             209        510     388-7540                 no
# 2708    MI             132        408     389-4608                 no
# 2710    WV              63        510     328-9797                 no
# 2724    NJ             182        415     418-8568                 no
# 2731    NJ             127        510     405-3309                 no
# 2732    NC             130        408     384-4938                yes
# 2735    TX              90        415     355-9366                yes
# 2745    PA              61        408     343-1347                 no
# 2747    MD             147        408     376-4292                 no
# 2760    IL             137        408     352-5787                yes
# 2772    WI             161        408     415-3537                 no
# 2773    NJ             134        510     373-3959                 no
# 2774    ME              62        415     358-1346                yes
# 2784    MD             119        408     401-9665                 no
# 2785    MN              38        510     399-5291                 no
# 2786    AR             109        415     409-6588                 no
# 2794    MT             137        408     330-5824                yes
# 2800    SD              52        510     403-6187                yes
# 2816    ID             130        415     358-3692                 no
# 2819    WY             159        415     391-2159                 no
# 2824    OR              81        415     406-4100                 no
# 2827    AL              89        510     347-2016                 no
# 2828    MS             123        415     388-8948                yes
# 2839    SC             112        415     363-8033                 no
# 2865    NH              97        408     328-9267                 no
# 2868    MA              17        415     376-4705                yes
# 2874    WY             134        510     366-1084                 no
# 2882    MI             178        408     348-4660                yes
# 2884    UT             170        415     397-6542                 no
# 2889    CT              93        415     404-4809                 no
# 2900    MS              78        408     361-7283                 no
# 2901    MT              85        408     372-4868                 no
# 2908    NV             148        415     406-7844                 no
# 2924    WA              96        415     406-2866                 no
# 2925    NY             168        408     333-5729                 no
# 2926    IN              72        510     391-1499                 no
# 2934    DC              24        408     369-3626                 no
# 2936    OK              44        408     358-7165                 no
# 2942    GA             117        415     328-5188                yes
# 2947    ND             145        415     378-1936                 no
# 2950    OH             133        408     380-4374                 no
# 2952    WY             123        415     387-1116                 no
# 2958    NC              95        408     384-3413                 no
# 2960    TX               1        415     396-4254                 no
# 2961    KY              98        415     333-3010                 no
# 2964    OR              99        408     353-3372                 no
# 2968    CT             160        415     360-2329                 no
# 2971    MI             148        415     385-1118                yes
# 2972    MT             147        415     408-8269                 no
# 2979    HI              99        408     413-9328                 no
# 2980    KS              84        415     335-7144                 no
# 2987    NY             131        408     406-8995                yes
# 2989    MI             108        408     341-9890                yes
# 2994    VT             128        408     344-1362                 no
# 3002    WA             177        415     345-3947                 no
# 3019    TX             169        408     379-5885                 no
# 3023    MT             103        510     342-1004                 no
# 3035    ME              88        415     405-5513                 no
# 3045    MN              57        415     348-5728                 no
# 3050    SC             101        415     345-4589                 no
# 3064    CO             130        408     349-3005                 no
# 3070    MD             154        510     411-2977                 no
# 3072    TX              75        415     417-4456                 no
# 3079    WV              88        510     421-1326                 no
# 3093    SD              27        510     359-3423                 no
# 3112    AR             115        415     385-7157                 no
# 3113    HI             108        415     385-4766                 no
# 3125    IA              40        510     389-8417                 no
# 3127    MT             100        415     341-4873                 no
# 3132    NC             161        415     394-5489                 no
# 3144    NH              35        408     393-8762                 no
# 3148    WA              60        415     366-8939                yes
# 3151    ME              56        408     385-5688                 no
# 3157    AR             127        415     416-3649                yes
# 3166    AR              54        415     337-1586                 no
# 3168    TX             201        415     415-5476                 no
# 3169    ID              78        415     332-2650                 no
# 3189    WA              76        510     345-6961                yes
# 3190    ID             103        415     346-5992                 no
# 3191    CT              87        415     402-3908                 no
# 3205    MS             111        408     345-3787                 no
# 3209    OH              68        415     369-8574                yes
# 3224    IN             115        415     370-9622                 no
# 3226    ME             100        510     351-2815                 no
# 3238    WA             121        510     378-1884                 no
# 3241    AK             177        415     384-6132                yes
# 3243    AR             113        415     338-6714                yes
# 3246    NC              77        408     334-6129                yes
# 3247    OK             146        510     377-4975                 no
# 3255    RI             138        510     411-6823                yes
# 3265    ID              82        415     408-1913                 no
# 3268    WA              84        415     367-5226                 no
# 3272    MD             133        510     373-7974                 no
# 3280    AR              76        408     345-3614                 no
# 3287    KS             170        415     404-5840                 no
# 3291    MI             119        510     335-7324                yes
# 3301    CA              84        415     417-1488                 no
# 3304    IL              71        510     330-7137                yes
# 3320    GA             122        510     411-5677                yes
# 3322    MD              62        408     409-1856                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 10                no                      0              129.1
# 15                no                      0              332.9
# 21                no                      0               62.4
# 33                no                      0              249.6
# 41               yes                     41              173.1
# 48                no                      0              159.1
# 54                no                      0              151.0
# 57               yes                     30              198.4
# 69                no                      0              178.9
# 76                no                      0              300.3
# 77                no                      0               61.6
# 84                no                      0              210.6
# 86                no                      0              157.9
# 89                no                      0              237.9
# 91                no                      0              203.4
# 98                no                      0              212.1
# 99                no                      0              251.8
# 115              yes                     42              196.8
# 117               no                      0              282.5
# 126               no                      0               70.7
# 127              yes                     27              187.5
# 144               no                      0              167.1
# 156               no                      0              337.4
# 181               no                      0               58.2
# 197               no                      0              326.5
# 198              yes                     26              292.9
# 214               no                      0              226.7
# 218               no                      0              250.2
# 230               no                      0              312.0
# 235               no                      0              134.4
# 241               no                      0              135.1
# 244               no                      0              198.5
# 250              yes                     29              157.4
# 258               no                      0               62.6
# 277              yes                     48              189.8
# 289               no                      0              303.9
# 293              yes                     37              172.7
# 301               no                      0              266.6
# 302               no                      0              170.4
# 306               no                      0              272.1
# 307               no                      0              296.4
# 310               no                      0              248.7
# 319              yes                     32              223.5
# 331               no                      0              272.6
# 332               no                      0              128.3
# 340               no                      0              213.0
# 349               no                      0              107.0
# 354               no                      0              236.2
# 360               no                      0              257.1
# 365               no                      0              350.8
# 372               no                      0              218.0
# 378               no                      0              165.5
# 394               no                      0              229.6
# 397               no                      0              234.4
# 399               no                      0              167.3
# 407               no                      0              157.1
# 415               no                      0              239.7
# 416               no                      0              171.5
# 430               no                      0              250.3
# 437               no                      0              278.0
# 454               no                      0              256.4
# 455               no                      0              264.8
# 465               no                      0              178.2
# 466              yes                     36              226.2
# 473              yes                     33               96.6
# 491               no                      0              191.9
# 492               no                      0              130.7
# 498               no                      0              211.3
# 502               no                      0              216.9
# 507               no                      0              154.0
# 509              yes                     26              170.8
# 514              yes                     29              265.9
# 521               no                      0               73.3
# 542              yes                     20              237.5
# 546               no                      0              279.8
# 547              yes                     41              136.8
# 550               no                      0              172.8
# 552               no                      0              288.1
# 558               no                      0              174.1
# 569              yes                     32              221.1
# 574               no                      0              228.1
# 580               no                      0              209.4
# 584               no                      0              234.2
# 588               no                      0               89.7
# 601               no                      0              159.7
# 605               no                      0              335.5
# 613              yes                     29              220.7
# 619               no                      0              293.3
# 626              yes                     37              220.2
# 629               no                      0              299.5
# 649               no                      0              261.7
# 655               no                      0              157.6
# 660               no                      0              264.7
# 679               no                      0              222.4
# 715               no                      0              249.9
# 721              yes                     36               87.2
# 730               no                      0              271.2
# 736               no                      0              162.1
# 737               no                      0              145.0
# 766               no                      0              230.9
# 771              yes                     28              126.9
# 773               no                      0              176.9
# 787               no                      0              265.6
# 792              yes                     33              271.5
# 797               no                      0              148.5
# 815               no                      0              314.6
# 830               no                      0              167.7
# 832               no                      0              322.5
# 846               no                      0              180.6
# 851               no                      0              199.6
# 859               no                      0              267.9
# 871               no                      0              271.4
# 892              yes                     27              166.9
# 894               no                      0              120.8
# 901               no                      0              321.6
# 904               no                      0              260.0
# 905               no                      0              191.9
# 911               no                      0              267.8
# 914               no                      0              287.3
# 933               no                      0              125.8
# 944              yes                     28              167.9
# 946               no                      0              257.4
# 966              yes                     22              152.0
# 968              yes                     33              174.9
# 975               no                      0              334.3
# 977              yes                     21              134.2
# 978               no                      0              278.0
# 985               no                      0              346.8
# 987              yes                     27              267.9
# 1000              no                      0              277.3
# 1018              no                      0              263.4
# 1027              no                      0              194.2
# 1030             yes                     42              216.0
# 1038              no                      0              111.9
# 1077              no                      0              154.2
# 1078              no                      0              322.3
# 1102              no                      0              176.9
# 1105             yes                     28              201.4
# 1115              no                      0              165.0
# 1121              no                      0              154.4
# 1122              no                      0              189.1
# 1133              no                      0              148.1
# 1136             yes                     26              270.3
# 1142              no                      0              106.4
# 1150              no                      0              193.3
# 1155              no                      0              131.6
# 1182              no                      0              287.1
# 1192              no                      0              235.1
# 1193             yes                     15              160.0
# 1204              no                      0              236.8
# 1231              no                      0              270.9
# 1232              no                      0              243.0
# 1240             yes                     34              162.1
# 1254             yes                     33              186.4
# 1263             yes                     31              224.7
# 1269             yes                     45              130.5
# 1273              no                      0              121.7
# 1276              no                      0              229.7
# 1278              no                      0              247.7
# 1280              no                      0              112.2
# 1284              no                      0              263.8
# 1299              no                      0              266.3
# 1302              no                      0              270.5
# 1306              no                      0              189.2
# 1310              no                      0               78.6
# 1322              no                      0              132.1
# 1325             yes                     31              153.1
# 1327              no                      0               96.8
# 1334              no                      0              321.3
# 1337              no                      0              236.9
# 1339              no                      0              148.2
# 1344              no                      0              284.4
# 1345              no                      0                0.0
# 1346              no                      0              133.7
# 1350              no                      0              285.7
# 1359              no                      0              217.8
# 1364              no                      0              245.0
# 1373              no                      0              112.0
# 1376              no                      0              245.7
# 1392              no                      0              269.7
# 1405              no                      0              143.2
# 1407             yes                     31               82.3
# 1420              no                      0              149.4
# 1435             yes                     19              112.6
# 1442              no                      0              195.7
# 1454             yes                     44              174.0
# 1467             yes                     35              181.1
# 1472              no                      0              273.3
# 1484              no                      0              133.3
# 1493             yes                     30              153.4
# ...
# 1614               3.73                       1   True
# 1619               3.29                       4   True
# 1635               2.57                       4   True
# 1638               2.62                       6   True
# 1646               2.67                       0   True
# 1651               4.67                       1   True
# 1653               3.00                       1   True
# 1662               3.70                       5   True
# 1674               2.67                       1   True
# 1679               2.86                       0   True
# 1691               1.97                       2   True
# 1692               1.70                       1   True
# 1694               3.11                       7   True
# 1701               2.97                       2   True
# 1702               2.08                       4   True
# 1704               3.13                       1   True
# 1707               1.51                       5   True
# 1713               2.03                       5   True
# 1718               2.62                       2   True
# 1731               3.48                       0   True
# 1736               1.86                       1   True
# 1739               1.57                       2   True
# 1746               3.65                       1   True
# 1750               1.86                       1   True
# 1752               3.81                       0   True
# 1754               2.62                       2   True
# 1764               2.03                       0   True
# 1765               3.43                       4   True
# 1768               2.92                       2   True
# 1777               2.70                       3   True
# 1784               3.81                       0   True
# 1794               3.11                       1   True
# 1804               2.59                       0   True
# 1837               2.32                       1   True
# 1842               2.40                       0   True
# 1844               3.11                       4   True
# 1845               3.75                       2   True
# 1849               3.75                       2   True
# 1850               2.51                       1   True
# 1851               2.94                       5   True
# 1857               3.27                       1   True
# 1861               2.08                       0   True
# 1862               2.16                       0   True
# 1865               2.13                       7   True
# 1866               2.40                       2   True
# 1869               3.65                       1   True
# 1878               3.11                       1   True
# 1880               4.00                       4   True
# 1881               2.08                       0   True
# 1887               3.97                       0   True
# 1889               2.78                       1   True
# 1892               2.67                       0   True
# 1893               2.40                       2   True
# 1898               2.00                       2   True
# 1903               3.78                       1   True
# 1904               3.92                       4   True
# 1912               2.81                       8   True
# 1919               2.57                       6   True
# 1933               2.70                       1   True
# 1934               2.35                       0   True
# 1935               3.67                       3   True
# 1939               2.48                       2   True
# 1950               1.89                       4   True
# 1954               3.19                       0   True
# 1965               3.00                       1   True
# 1974               2.35                       5   True
# 1977               4.21                       2   True
# 1978               3.59                       3   True
# 1984               4.43                       3   True
# 2001               2.89                       1   True
# 2028               2.35                       1   True
# 2029               3.89                       0   True
# 2033               2.81                       2   True
# 2038               2.73                       1   True
# 2059               2.40                       3   True
# 2069               2.65                       0   True
# 2076               2.73                       4   True
# 2099               2.73                       3   True
# 2103               2.62                       2   True
# 2106               3.67                       0   True
# 2107               2.73                       2   True
# 2112               3.29                       4   True
# 2113               3.16                       2   True
# 2115               4.10                       0   True
# 2118               2.65                       0   True
# 2119               3.13                       0   True
# 2139               3.24                       3   True
# 2142               3.38                       1   True
# 2147               3.43                       3   True
# 2150               3.40                       2   True
# 2155               3.24                       2   True
# 2158               3.56                       0   True
# 2160               2.13                       1   True
# 2164               2.67                       3   True
# 2173               3.59                       0   True
# 2186               2.94                       3   True
# 2187               3.35                       4   True
# 2203               2.97                       4   True
# 2210               3.16                       0   True
# 2213               3.35                       0   True
# 2215               3.11                       0   True
# 2218               3.05                       5   True
# 2237               1.84                       4   True
# 2238               4.67                       1   True
# 2258               1.94                       1   True
# 2267               3.46                       2   True
# 2283               1.27                       5   True
# 2290               2.89                       3   True
# 2324               2.11                       4   True
# 2325               2.65                       2   True
# 2327               2.54                       6   True
# 2335               2.70                       3   True
# 2343               3.73                       1   True
# 2347               3.65                       1   True
# 2354               3.54                       2   True
# 2356               1.57                       2   True
# 2357               2.73                       1   True
# 2369               2.43                       4   True
# 2376               1.57                       1   True
# 2377               2.38                       1   True
# 2380               2.73                       9   True
# 2386               2.00                       2   True
# 2387               2.46                       6   True
# 2388               2.40                       1   True
# 2389               2.86                       0   True
# 2397               3.56                       1   True
# 2401               3.08                       1   True
# 2402               4.13                       5   True
# 2405               1.73                       1   True
# 2407               3.62                       1   True
# 2412               2.03                       1   True
# 2415               2.43                       5   True
# 2419               2.40                       2   True
# 2420               3.13                       2   True
# 2421               2.94                       4   True
# 2428               3.05                       6   True
# 2432               3.59                       4   True
# 2437               2.24                       4   True
# 2451               2.89                       2   True
# 2468               1.16                       1   True
# 2472               2.75                       1   True
# 2479               3.16                       3   True
# 2489               2.84                       4   True
# 2493               3.05                       5   True
# 2515               3.24                       5   True
# 2526               1.73                       0   True
# 2533               3.32                       2   True
# 2535               2.48                       2   True
# 2536               2.43                       0   True
# 2539               2.89                       3   True
# 2542               2.57                       1   True
# 2567               2.51                       2   True
# 2572               2.81                       1   True
# 2573               3.46                       1   True
# 2575               4.19                       1   True
# 2581               3.48                       4   True
# 2591               2.38                       1   True
# 2594               3.19                       1   True
# 2595               2.27                       1   True
# 2599               2.38                       0   True
# 2602               3.08                       2   True
# 2606               4.35                       1   True
# 2614               3.29                       0   True
# 2619               3.00                       3   True
# 2624               3.13                       0   True
# 2629               1.81                       1   True
# 2645               3.27                       2   True
# 2647               3.62                       0   True
# 2660               3.62                       4   True
# 2662               3.70                       2   True
# 2664               3.89                       1   True
# 2666               3.27                       1   True
# 2672               2.48                       0   True
# 2673               1.81                       3   True
# 2677               1.97                       4   True
# 2681               3.59                       0   True
# 2687               4.59                       1   True
# 2694               2.73                       0   True
# 2696               3.32                       3   True
# 2700               2.30                       3   True
# 2708               2.40                       1   True
# 2710               3.97                       0   True
# 2724               2.57                       2   True
# 2731               3.75                       0   True
# 2732               4.56                       5   True
# 2735               3.59                       0   True
# 2745               2.75                       2   True
# 2747               1.67                       0   True
# 2760               3.83                       0   True
# 2772               1.59                       4   True
# 2773               1.65                       2   True
# 2774               3.56                       0   True
# 2784               2.94                       3   True
# 2785               2.48                       5   True
# 2786               2.43                       6   True
# 2794               2.94                       0   True
# 2800               2.97                       0   True
# 2816               4.94                       1   True
# 2819               2.78                       0   True
# 2824               3.54                       0   True
# 2827               2.78                       5   True
# 2828               1.70                       4   True
# 2839               3.83                       2   True
# 2865               2.32                       2   True
# 2868               3.67                       0   True
# 2874               3.32                       0   True
# 2882               3.08                       2   True
# 2884               2.35                       1   True
# 2889               2.27                       1   True
# 2900               2.13                       1   True
# 2901               2.51                       4   True
# 2908               2.13                       2   True
# 2924               2.78                       1   True
# 2925               3.13                       2   True
# 2926               1.35                       4   True
# 2934               2.32                       2   True
# 2936               2.57                       0   True
# 2942               2.70                       1   True
# 2947               2.43                       1   True
# 2950               3.19                       0   True
# 2952               2.21                       5   True
# 2958               1.70                       6   True
# 2960               2.70                       5   True
# 2961               2.16                       6   True
# 2964               2.13                       3   True
# 2968               3.75                       1   True
# 2971               2.59                       0   True
# 2972               2.73                       2   True
# 2979               2.38                       7   True
# 2980               3.86                       3   True
# 2987               3.70                       3   True
# 2989               3.73                       2   True
# 2994               1.49                       1   True
# 3002               2.40                       3   True
# 3019               3.73                       3   True
# 3023               3.75                       4   True
# 3035               3.13                       4   True
# 3045               2.84                       2   True
# 3050               3.65                       4   True
# 3064               2.35                       4   True
# 3070               3.24                       3   True
# 3072               2.30                       0   True
# 3079               2.13                       5   True
# 3093               2.21                       2   True
# 3112               2.51                       7   True
# 3113               3.78                       2   True
# 3125               2.84                       4   True
# 3127               3.16                       4   True
# 3132               2.11                       2   True
# 3144               2.78                       5   True
# 3148               2.97                       0   True
# 3151               1.92                       0   True
# 3157               1.67                       4   True
# 3166               2.75                       2   True
# 3168               3.02                       1   True
# 3169               3.24                       4   True
# 3189               3.56                       0   True
# 3190               4.27                       6   True
# 3191               2.51                       0   True
# 3205               2.92                       1   True
# 3209               3.83                       3   True
# 3224               3.32                       3   True
# 3226               2.03                       2   True
# 3238               2.38                       3   True
# 3241               3.05                       1   True
# 3243               2.78                       5   True
# 3246               3.21                       0   True
# 3247               1.05                       4   True
# 3255               2.97                       2   True
# 3265               2.97                       3   True
# 3268               3.43                       2   True
# 3272               3.48                       2   True
# 3280               2.70                       4   True
# 3287               2.94                       4   True
# 3291               3.75                       1   True
# 3301               2.81                       0   True
# 3304               3.73                       4   True
# 3320               2.62                       4   True
# 3322               3.11                       4   True
# 3323               3.67                       5   True

# %% [markdown]
# ### Filtrar por varias condiciones

# %%
df[ (df['churn']==False) & (df['international plan']=='No')]
# Out:
# Empty DataFrame
# Columns: [state, account length, area code, phone number, international plan, voice mail plan, number vmail messages, total day minutes, total day calls, total day charge, total eve minutes, total eve calls, total eve charge, total night minutes, total night calls, total night charge, total intl minutes, total intl calls, total intl charge, customer service calls, churn]
# Index: []

# %% [markdown]
# ## Modificación del Dataframe

# %% [markdown]
# #### Añadir una columna basandose en otras

# %%
df["prueba"] = df["account length"] * 10
df["prueba"] = df["account length"].apply(lambda x: x + 1)
df["prueba2"] = df["international plan"].map(dict(Yes=1, No=0))

# %% [markdown]
# #### Borrar variables

# %%
del df['prueba'] # opción 1

# %%
df = df.drop(['prueba2'], axis=1) # Opción 2

# %% [markdown]
# #### Cambiar tipo de la variable

# %%
df['area code'] = df['area code'].astype(object)

# %% [markdown]
# # <center> Fin
